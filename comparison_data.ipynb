# %% [markdown]
# <a href="https://colab.research.google.com/github/kevin-rn/Grounding-LM/blob/main/comparison_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install -q datasets
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 12.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 10.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 16.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 12.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 42.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 15.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 11.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 26.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 15.8 MB/s eta 0:00:00

# %%
import pandas as pd
from datasets import load_from_disk

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cp -R ./drive/MyDrive/data ./

# %%
df_t5 = pd.read_csv("data/generated_summaries/T5_xsum.csv")
df_t5
# Out:
#              id                                          generated
# 0      30475232  A London-bound train traveller has been banned...
# 1      35973760  Atletico Madrid defender Luis Suarez says his ...
# 2      38909077  Mae llywodraeth Cymru byddai'r cynllun yn cost...
# 3      35777239  A medical practice manager has admitted steali...
# 4      38796977  Ghana coach Ehud Grant says he would like to s...
# ...         ...                                                ...
# 11329  38928528                                 No boss is needed.
# 11330  33048504  A three-year-old girl has been treated for a b...
# 11331  39770896  A woman and her two-year-old daughter have bee...
# 11332  38711418  Theresa May has refused to say if she knew abo...
# 11333  35002961  Japan's shares fell after the European Central...
#
# [11334 rows x 2 columns]

# %%
df_bart = pd.read_csv("data/generated_summaries/bart_xsum.csv")
df_merge = pd.merge(df_t5, df_bart, on='id')
df_merge.columns = ['id', 'T5_xsum', 'bart_xsum']
df_merge
# Out:
#              id                                            T5_xsum  \
# 0      30475232  A London-bound train traveller has been banned...
# 1      35973760  Atletico Madrid defender Luis Suarez says his ...
# 2      38909077  Mae llywodraeth Cymru byddai'r cynllun yn cost...
# 3      35777239  A medical practice manager has admitted steali...
# 4      38796977  Ghana coach Ehud Grant says he would like to s...
# ...         ...                                                ...
# 11329  38928528                                 No boss is needed.
# 11330  33048504  A three-year-old girl has been treated for a b...
# 11331  39770896  A woman and her two-year-old daughter have bee...
# 11332  38711418  Theresa May has refused to say if she knew abo...
# 11333  35002961  Japan's shares fell after the European Central...
#
#                                                bart_xsum
# 0      kowski train at this Stonegatet an in. get Aft...
# ...

# %%
data = load_from_disk('data/xsum')
df_xsum_test = pd.DataFrame(data=data['test'])
df_xsum_test.columns = ['text', 'summary', 'id']
df_xsum_test
# Out:
#                                                     text  \
# 0      Prison Link Cymru had 1,099 referrals in 2015-...
# 1      Officers searched properties in the Waterfront...
# 2      Jordan Hill, Brittany Covington and Tesfaye Co...
# 3      The 48-year-old former Arsenal goalkeeper play...
# 4      Restoring the function of the organ - which he...
# ...                                                  ...
# 11329  Amnesty International supporters are zipped in...
# 11330  The project was launched in Grenada by the pri...
# 11331  The world number two won 6-2 6-0 in 66 minutes...
# 11332  Mr Pistorius says he mistakenly shot his girlf...
# 11333  Media playback is unsupported on your device\n...
#
#                                                  summary        id
# 0      There is a "chronic" need for more housing for...  38264402
# 1      A man has appeared in court after firearms, am...  34227252
# 2      Four people accused of kidnapping and torturin...  38537698
# ...

# %%
df_xsum_test['id']=df_xsum_test['id'].astype(int)
df_merge = pd.merge(df_xsum_test, df_merge, on='id')
df_merge
# Out:
#                                                     text  \
# 0      Prison Link Cymru had 1,099 referrals in 2015-...
# 1      Officers searched properties in the Waterfront...
# 2      Jordan Hill, Brittany Covington and Tesfaye Co...
# 3      The 48-year-old former Arsenal goalkeeper play...
# 4      Restoring the function of the organ - which he...
# ...                                                  ...
# 11329  Amnesty International supporters are zipped in...
# 11330  The project was launched in Grenada by the pri...
# 11331  The world number two won 6-2 6-0 in 66 minutes...
# 11332  Mr Pistorius says he mistakenly shot his girlf...
# 11333  Media playback is unsupported on your device\n...
#
#                                                  summary        id  \
# 0      There is a "chronic" need for more housing for...  38264402
# 1      A man has appeared in court after firearms, am...  34227252
# 2      Four people accused of kidnapping and torturin...  38537698
# ...
